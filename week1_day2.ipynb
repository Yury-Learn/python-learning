# %% [markdown]
# # Week1 Day2 — ввод и проверка чётности числа
#
# Цели этой сессии:
# - Научиться получать ввод пользователя через `input()`
# - Понять преобразование типов (строка -> целое число) с помощью `int(...)`
# - Научиться проверять число на чётность через оператор `%`
# - Научиться запускать код ячейками внутри VS Code без внешнего браузера
#
# Контекст:
# Этот ноутбук выполняется в виртуальном окружении `.venv` проекта `python-learning`.
# Все библиотеки (включая Jupyter) ставятся через `pip` только внутрь этого окружения.
# Это тот же Python, что будет использоваться в моих реальных скриптах `.py`.

# %%
x = 10
y = 32

result = x + y

print("x =", x)
print("y =", y)
print("result =", result)
print("Тип result:", type(result))
# Out:
# x = 10
# y = 32
# result = 42
# Тип result: <class 'int'>

# %%
# Эта ячейка:
# 1. Спрашивает число у пользователя.
# 2. Превращает введённую строку в целое число (int).
# 3. Проверяет чётность через оператор % (остаток от деления).

# raw_number: строка, которую пользователь ввёл.
# input("Введи число: ") показывает приглашение "Введи число: "
# и ждёт пока пользователь введёт что-то и нажмёт Enter.
raw_number = input("Введи число: ")

# int(raw_number) пытается преобразовать строку в целое число.
# Пример:
#   "10" -> 10
#   "42" -> 42
# Если пользователь введёт, например, "кот", будет ошибка ValueError,
# потому что строку "кот" нельзя преобразовать к числу.
number = int(raw_number)

# number % 2 — это остаток от деления на 2.
# Примеры:
#   10 % 2 == 0  -> число чётное
#   11 % 2 == 1  -> число нечётное
if number % 2 == 0:
    print("Число чётное")
else:
    print("Число нечётное")

# Для наглядности выведем типы:
print("Сырые данные (raw_number):", raw_number, "| тип:", type(raw_number))
print("После преобразования (number):", number, "| тип:", type(number))
# Out:
# Число чётное
# Сырые данные (raw_number): 44 | тип: <class 'str'>
# После преобразования (number): 44 | тип: <class 'int'>

# %% [markdown]
# ## Мой рабочий процесс с Git и GitHub
#
# Цель: вести учебный проект `python-learning` так же, как настоящий рабочий код.
#
# ### 1. Просмотр изменений
# В VS Code слева есть вкладка Source Control (иконка с ответвлением).
# Там я вижу список файлов, которые были изменены или созданы:
# - новые `.py` файлы (например, `week1_day1.py`)
# - новые ноутбуки `.ipynb` (например, `week1_day2.ipynb`)
# - файлы документации (`README.md`)
# - служебные файлы, например `.gitignore`
#
# ### 2. Добавление комментария к коммиту
# В поле "Message" (Commit Message) я пишу осмысленное сообщение на английском или русском.
# Пример:
# - `Week1 Day2: input(), int(), проверка чётности в Jupyter`
# - `Add .venv-based Jupyter setup and README`
#
# Это важно: хороший коммит сразу объясняет, ЧТО я сделал и ЗАЧЕМ.
#
# ### 3. Коммит (Commit)
# Я нажимаю кнопку Commit (галочка).
# Это создаёт локальный снимок состояния проекта:
# - какие файлы добавлены,
# - какие строки изменились,
# - какой у них текст сейчас.
#
# Коммит = точка сохранения проекта во времени.
#
# ### 4. Push (отправка в GitHub)
# После коммита VS Code предлагает "Push" или "Sync Changes".
# Я нажимаю, и изменения уходят в удалённый репозиторий на GitHub.
#
# GitHub теперь хранит:
# - мой код `.py` (скрипты, которые можно запускать в терминале)
# - мои ноутбуки `.ipynb` (пояснения, эксперименты, ввод через input(), разбор типов)
# - README.md с описанием проекта
#
# ### Почему это важно для меня
# - Это портфолио: показывает, что я не просто копипастю код, а учусь как инженер.
# - Это журнал: я могу вернуться к любому коммиту и понять, что я делал на "Week1 Day2".
# - Это дисциплина DevOps: код + документация + воспроизводимость окружения (`.venv`) = инженерный подход.
